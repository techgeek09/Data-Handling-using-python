# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#random data generate
#seaborn already consist of a dataset
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
# plt.scatter()
sns.scatterplot(x='tip',y='total_bill',data=df)
plt.show()

# %%
#sns.barplot
# sns.histogram()
# sns.lineplot()
# sns.boxplot()
# sns.countplot

# %%
df['day'].value_counts() #Number of people in restaurent on a particular day
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
sns.countplot(df['day']) #only for categorical columns kyuki numerical columns kafi zada hote hai
plt.show()

# %%
sns.countplot(df['smoker'])
plt.show()

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# df

# %%
sns.relplot(x='tip',y='total_bill',data=df,hue='sex',style='smoker') # hue-differentiate on the basis on sex
plt.show()

# %%
sns.relplot(x='tip',y='total_bill',data=df,hue='time',style='smoker',col='day') # hue-differentiate on the basis on sex
plt.show() #outier-exception-on thursday 1 person is doing dinner

# %%
sns.relplot(x='total_bill',y='size',data=df) 
#discrete nature moving in positive direction

# %%
df[['total_bill','tip','size']].corr() #correlation-exact value of how column is related to eachother
#if tota; bill increase then the tip increases by 67 percent
#range=-1 to 1
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='tip',y='total_bill',data=df,hue='sex',kind='line') #kind=line to create a line plot and scatter can be created without creating scatter kind
#relplot can only make scatter or line plot
plt.show()

# %%
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
## 1 column is nuerical and the other categorical
# we will use the categorical column as the target variable

sns.catplot(x='smoker',y='total_bill',data=df)
plt.show()

# %%
sns.catplot(x='smoker',y='total_bill',data=df,hue='sex',kind='boxen')
plt.show()

# %%
sns.catplot(x='smoker',y='total_bill',data=df,kind='bar')
plt.show()

# %%
## 1 column is nuerical and the other categorical
# we will use the categorical column as the target variable

sns.catplot(x='smoker',y='total_bill',data=df,kind='box')
plt.show()

# %%
## 1 column is nuerical and the other categorical
# we will use the categorical column as the target variable

sns.catplot(x='smoker',y='total_bill',data=df,kind='swarm')
plt.show()

# %%
## 1 column is nuerical and the other categorical
# we will use the categorical column as the target variable

sns.catplot(x='smoker',y='total_bill',data=df,kind='point') #joins both the averages-total bill of smoker is higher than smokers
plt.show()

# %%
sns.catplot(x='smoker',data=df,kind="count")
plt.show()

# %%
sns.displot(df['total_bill'])
plt.show()

# %%
sns.histplot(df['total_bill'])
plt.show()

# %%
sns.kdeplot(df['total_bill']) #kde-kernel density estimator
plt.show()

# %%
sns.displot(df['total_bill'], kde='True',color='red')
plt.title('Histogram with kde')
plt.show()

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.kdeplot(df['size'])
plt.show()

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
